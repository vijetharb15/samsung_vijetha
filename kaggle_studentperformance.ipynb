# %% [markdown]
# <a href="https://colab.research.google.com/github/vijetharb15/samsung_vijetha/blob/main/kaggle_studentperformance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q kagglehub

# %% [markdown]
# #https://www.kaggle.com/datasets/waqi786/student-performance-dataset

# %%
import kagglehub
import pandas as pd
import os
###############################################################
# Specify the dataset identifier (user/dataset-name) and the file within the dataset
dataset_owner = "waqi786"
dataset_name = "student-performance-dataset"
dataset_handle = f"{dataset_owner}/{dataset_name}"
###############################################################
# Download the dataset to a local directory
local_path = kagglehub.dataset_download(dataset_handle)
###############################################################
# List the contents of the downloaded directory to find the correct file path
print(f"Dataset downloaded to: {local_path}")
###############################################################
print("Contents of the dataset:")
###############################################################
for root, dirs, files in os.walk(local_path):
    level = root.replace(local_path, '').count(os.sep)
    indent = ' ' * 4 * (level)
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 4 * (level + 1)
    for f in files:
        print(f'{subindent}{f}')
###############################################################
# Once you find the correct file path, replace "crime_statistics.csv"
# with the correct path and uncomment the line below to load the data into a DataFrame.
file_path_within_dataset = "student_performance_data.csv"
###############################################################
df = pd.read_csv(os.path.join(local_path, file_path_within_dataset))
###############################################################
# display(df.head())
df.head()
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/waqi786/student-performance-dataset?dataset_version_number=1...
# 100%|██████████| 5.92k/5.92k [00:00<00:00, 8.39MB/s]
# Extracting files...
# Dataset downloaded to: /root/.cache/kagglehub/datasets/waqi786/student-performance-dataset/versions/1
# Contents of the dataset:
# 1/
#     student_performance_data.csv
#    StudentID  Gender  Age  StudyHoursPerWeek  AttendanceRate   GPA      Major  \
# 0          1    Male   24                 37           90.75  3.47       Arts
# 1          2  Female   22                 37           74.90  2.32  Education
# 2          3    Male   22                 10           53.36  2.38   Business
# 3          4    Male   24                 10           70.26  3.46    Science
# 4          5    Male   18                 19           74.87  2.31  Education
#
#   PartTimeJob ExtraCurricularActivities
# 0         Yes                        No
# 1          No                        No
# 2          No                        No
# 3         Yes                        No
# 4         Yes                        No
